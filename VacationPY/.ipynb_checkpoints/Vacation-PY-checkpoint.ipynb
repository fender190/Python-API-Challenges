# %%
# Import and set all required dependencies
import gmaps
import os
import json
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests


# Import Google API key
from config import g_key

# %%
# load city list from weatherpy challenge
# Print df results
file = pd.read_csv("city_list.csv")
file.dropna()
file.head()
# Out:
#    City ID        City  Cloudiness Country        Date  Humidity    Lat  \
# 0        0      Albany          40      US  1570758446        50  42.65
# 1        1  Nikolskoye          90      RU  1570758446        93  59.70
# 2        2       Bluff          25      AU  1570758446        34 -23.58
# 3        3     Tautira          20      PF  1570758446        61 -17.73
# 4        4      Bethel          90      US  1570758446       100  60.79
#
#       Lng  Max Temp  Wind Speed
# 0  -73.75     57.20        5.82
# 1   30.79     44.60        3.66
# 2  149.07     81.18        3.05
# 3 -149.15     82.40        8.05
# 4 -161.76     39.20       16.11

# %%
# Set Gmaps with the G-key
gmaps.configure(api_key=g_key)

# Store 'Lat' and 'Lng' from DF into lists
locations = file[["Lat", "Lng"]]
humidity = file["Humidity"].astype(float)

# %%
# Heatmap
fig = gmaps.figure(center = [0,0] ,zoom_level = 2)

# Add heat layer over map 
heat_layer = gmaps.heatmap_layer(locations, weights=humidity,
                               dissipating=False, max_intensity=100,
                               point_radius = 4)
fig.add_layer(heat_layer)
#Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# configuration of perfect conditions (my perfect conditions)
temp_file=file.loc[(file['Max Temp']>=60)&(file['Max Temp']<=90)]
wind_file=temp_file.loc[(temp_file['Wind Speed']<=5)]
ideal_weather=wind_file.loc[(wind_file['Cloudiness']==0)]
ideal_weather.head()
# Out:
#     City ID             City  Cloudiness Country        Date  Humidity    Lat  \
# 50       50          Colares           0      PT  1570758452        55  38.80
# 57       57             Jian           0      IN  1570758453        68  25.65
# 67       67        Iranshahr           0      IR  1570758454        22  27.21
# 75       75  Phra Phutthabat           0      TH  1570758455        79  14.72
# 95       95     Saint-Joseph           0      FR  1570758458        87  43.56
#
#        Lng  Max Temp  Wind Speed
# 50   -9.45     64.99        3.36
# 57   87.89     82.15        2.39
# 67   60.69     79.16        2.66
# 75  100.80     88.00        1.72
# 95    6.97     60.80        3.36

# %%
# create hotel file
hotel_df = ideal_weather.reset_index(drop=True)
hotel_df["Hotel Name"] = ""

# parameters
params = {
    "radius": 50000,
    "types": "hotel",
    "keyword": "hotels",
    "key": g_key
}

# Use the lat/lng we recovered to identify hotels
for index, row in hotel_df.iterrows():
    
    # latitudes and longitudes from df
    lat = row["Lat"]
    lng = row["Lng"]
    
    # change location each iteration while leaving original params in place
    params["location"] = f"{lat},{lng}"
    
    # Use the search term: "Hotels" and our lat/lng
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    
    # make request and print url
    hotel_name = requests.get(base_url, params=params)
    
    # convert to json
    hotel_name = hotel_name.json()
    print(json.dumps(hotel_name, indent=4, sort_keys=True))
    
    # Since some data may be missing we incorporate a try-except to skip any that are missing a data point.
    try:
        hotel_df.loc[index, "Hotel Name"] = hotel_name["results"][0]["name"]
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
hotel_df
# Out:
# {
#     "html_attributions": [],
#     "next_page_token": "CrQCJAEAAAR71kxAQ8PXYtmFt2fCvLidsOqFT7vpAo7YsC8TgnIqx9yWB9TKOkwUWWgouwXvaQb8htW-0V8gzCWno9p3yO0w79U_dhCT3eH9RS0Id_rZEX6OYvdAbWPQsTKlomgLk3E98iovVbtcAEFGtsdu0_5JrzzTNU6cZUQNfWfPztLjtbI9ih26AFxkXOo4pVAMJjWeN3Ocg2QpTmUDTSTWfal3Y1zJLc4LUdmMSv8XS-4I7ZUDzyBlsdJZB_BoLRsF8-gP71NfqpCtgmsjPay606z_BLyW42wqeET1HK8F4OOMiRSGUX33k7QLDR08Z2Rs1rupiRhlePuheQ61Pm-22AYpTUkXAsPv0iy-TjDkLzkPj5xOpP7r6n-Ia4uPhmrvMXgKfirAzW1BPDvXZWMXWgYSELEAEdeRwNWAAF7tu_StCmEaFFTwIgPAPn8bEGppzE79cUrn-5ek",
#     "results": [
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 38.7101109,
#                     "lng": -9.460852599999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 38.71151952989273,
#                         "lng": -9.459536620107277
#                     },
#                     "southwest": {
#                         "lat": 38.70881987010728,
#                         "lng": -9.462236279892721
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "2153db3ba6d31e97241475ea6d647130a4204bb2",
#             "name": "Sheraton Cascais Resort",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3744,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/106569884941786161773/photos\">Sheraton Cascais Resort</a>"
#                     ],
#                     "photo_reference": "CmRaAAAATdaxBPR4TMKCVoKbWSEfgWMCDk9hEBn6hlVlOOtHbn_A8s6MUF6_bd8GuZkJpeh00p5gNJfT-RZZFpQoGHRh8-cOqXXKgHL-MvYRv9TsK8fuwhIoQ1a0zeS8GrZ_S513EhDhK03qN-S0O4Pkd-FgocqsGhRSk2lrewYJSTpKmWWZDKLnImM2og",
#                     "width": 5616
#                 }
#             ],
#             "place_id": "ChIJKxvCZYvDHg0RIelvZYO4fHI",
#             "plus_code": {
#                 "compound_code": "PG6Q+2M Cascais, Portugal",
#                 "global_code": "8CCGPG6Q+2M"
#             },
#             "rating": 4.5,
#             "reference": "ChIJKxvCZYvDHg0RIelvZYO4fHI",
#             "scope": "GOOGLE",
#             "types": [
#                 "spa",
#                 "lodging",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 998,
#             "vicinity": "R. das Palmeiras Lote 5, Cascais"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 38.69690569999999,
#                     "lng": -9.289046899999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 38.69826652989272,
#                         "lng": -9.287682420107279
#                     },
#                     "southwest": {
#                         "lat": 38.69556687010728,
#                         "lng": -9.290382079892723
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "bfc41f11098bdd0c03a415305d7e25778b1a0a93",
#             "name": "Hotel Vila Gal\u00e9 Collection Pal\u00e1cio dos Arcos",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1001,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/108785034308486330391/photos\">Hotel Vila Gal\u00e9 Collection Pal\u00e1cio dos Arcos</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAq39KgIYZSyej-pmGhY_1CIqP-NNgE7_sD_7G7U1_kDzWj8JeoAMY1c0mGHUZAo3KmVrv98DpsFNIA2h9ncJxyKPGbGjusx0aVgmx0N3Y-CtBFGDOOD8ira8aQRxzq62FEhAYPuQeZ8AHXdX326lnJYT7GhQMN7olTFne6oHoYnxhTvBOr5pOtA",
#                     "width": 1500
#                 }
#             ],
#             "place_id": "ChIJI4lTBVLJHg0R9yYsjj8oQp4",
#             "plus_code": {
#                 "compound_code": "MPW6+Q9 Pa\u00e7o de Arcos, Portugal",
#                 "global_code": "8CCGMPW6+Q9"
#             },
#             "rating": 4.7,
#             "reference": "ChIJI4lTBVLJHg0R9yYsjj8oQp4",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 698,
#             "vicinity": "Largo Conde das Alc\u00e1\u00e7ovas 3, Pa\u00e7o de Arcos"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 38.69034,
#                     "lng": -9.422225
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 38.69182882989273,
#                         "lng": -9.421011220107276
#                     },
#                     "southwest": {
#                         "lat": 38.68912917010728,
#                         "lng": -9.42371087989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "57f997c795a182a85b9168f308437d468e9f37e4",
#             "name": "Farol Hotel",
#             "photos": [
#                 {
#                     "height": 800,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/102806345979062277906/photos\">Farol Design Hotel</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAcnwmteD7pfHaevYrpRC7elbDbiJ0jk7Q0LPTrri9fw7-kLgz4apoz7a0ZGMOFJQgkJJOxt51z6z0yu4JPHWISIcTHBTihYYunLqdw62b_KOI0IC8niFWiELGYfRj5GGHEhDLwukKkvcu0zDP1eRV33thGhQZZ9m-Ibz-hINzIhlgIUocDyDGNw",
#                     "width": 532
#                 }
#             ],
#             "place_id": "ChIJzRkNr4LGHg0RpLlSR5B7iJ4",
#             "plus_code": {
#                 "compound_code": "MHRH+44 Cascais, Portugal",
#                 "global_code": "8CCGMHRH+44"
#             },
#             "rating": 4.5,
#             "reference": "ChIJzRkNr4LGHg0RpLlSR5B7iJ4",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 626,
#             "vicinity": "Av. Rei Humberto II de Italia 7, Cascais"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 38.7098772,
#                     "lng": -9.1506283
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 38.71121367989272,
#                         "lng": -9.149308770107277
#                     },
#                     "southwest": {
#                         "lat": 38.70851402010727,
#                         "lng": -9.152008429892721
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "6d669d506d7e3e43b9dcd81979eb0a2263e7c03c",
#             "name": "Selina Secret Garden Lisbon",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3840,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/110010215755556168031/photos\">A Google User</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAg-9gyaPvaFzJejFbOVwW8wJv1KGiR_zUd7EdFyPJc1hfe5-dqo8y5mvhcnJfPCYBHjG0laS_xkl26BEKIExWlMGUz8buZXL2cLpIcUPGfJgeW1pYPQsfb7fTNV2NM27BEhDgYz5_z6qlixWos0tZxIhPGhRSVVW_DJUW7EWDATTkTB4LPnmy5A",
#                     "width": 5760
#                 }
#             ],
#             "place_id": "ChIJEdXre4E0GQ0RgyYZ5m6ID-k",
#             "plus_code": {
#                 "compound_code": "PR5X+XP Lisbon, Portugal",
#                 "global_code": "8CCGPR5X+XP"
#             },
#             "rating": 4.4,
#             "reference": "ChIJEdXre4E0GQ0RgyYZ5m6ID-k",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 144,
#             "vicinity": "Beco Carrasco n\u00ba1, Lisboa"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 38.6910139,
#                     "lng": -9.4234384
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 38.69254667989272,
#                         "lng": -9.422254070107277
#                     },
#                     "southwest": {
#                         "lat": 38.68984702010728,
#                         "lng": -9.42495372989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "0cccc729a898bf2693584014a8691345033cf1c9",
#             "name": "Grande Real Villa It\u00e1lia Hotel & Spa",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1920,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/105924879539469539005/photos\">Grande Real Villa Italia Hotel &amp; Spa</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAI5iOVP8onp0YcWA6eWw6HJhozsocSyGRyp2pu5y--_THMQBOOnsRxRh_mVgSXCfOXS3Gkvod1IQJn5tdEV1GYAoA9WtLvlguQbJQwodTU_unLFCSyN8Mtslf_85Pza0EEhC3Q0BxucX4p6ArN0gBP0hgGhQbkfPMDrvxLSjDjRx1zTOzuBU5hQ",
#                     "width": 2880
#                 }
#             ],
#             "place_id": "ChIJuZcrXp3GHg0RS1mEgQTIPow",
#             "plus_code": {
#                 "compound_code": "MHRG+CJ Cascais, Portugal",
#                 "global_code": "8CCGMHRG+CJ"
#             },
#             "rating": 4.7,
#             "reference": "ChIJuZcrXp3GHg0RS1mEgQTIPow",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1111,
#             "vicinity": "R. Frei Nicolau de Oliveira 100, Cascais"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 38.7284419,
#                     "lng": -9.476023699999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 38.72980867989272,
#                         "lng": -9.474606920107279
#                     },
#                     "southwest": {
#                         "lat": 38.72710902010728,
#                         "lng": -9.477306579892723
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "3f3131a31e2ef779e18da2209960d4e53f0e8058",
#             "name": "Fortaleza do Guincho",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 1367,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/108342106263738588398/photos\">HOTEL FORTALEZA DO GUINCHO</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAiaHRnFXcme27q-WvxaM6HvjC-QasA0N8gJ0W6cKeA_4BflUe64PT_z5n34BP-iZKj_uaHcU9eiODHgU4k5-o0xXdsELvW8FtexpP15Q826urulWSGk7nFNRSfaxm-UUeEhDNlnMiszbcb_qVeDL6jTWuGhTfvN3HAukVDVuU9yVNfBbDOgBXTg",
#                     "width": 2048
#                 }
#             ],
#             "place_id": "ChIJO-t2cnbDHg0RbT9KwBQBwJc",
#             "plus_code": {
#                 "compound_code": "PGHF+9H Cascais, Portugal",
#                 "global_code": "8CCGPGHF+9H"
#             },
#             "rating": 4.6,
#             "reference": "ChIJO-t2cnbDHg0RbT9KwBQBwJc",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 586,
#             "vicinity": "Praia do Guincho, Cascais"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 38.7035895,
#                     "lng": -9.466880699999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 38.70494292989272,
#                         "lng": -9.465492270107278
#                     },
#                     "southwest": {
#                         "lat": 38.70224327010727,
#                         "lng": -9.468191929892722
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "d8fca9cef6a0c7645f592989e1f9bda891dc1401",
#             "name": "The Oitavos",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 667,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/111562308580123046830/photos\">The Oitavos</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAbPR25BPRPOS64wmZIExP0Ey-kQqSlulmTqcYMux8ivgtaMTuCFRhcqNtk_x_i0l8jbkRNmM_UbQfbGtq95qtYotafX6_im0s_ivG9-XOtWwPPBy6aMKRzPFssFWw0KmeEhDECInK6XEPwlb1EWIxMQ22GhS_uMdSJkfi-0FnHg0A7G2xq3r-6Q",
#                     "width": 1000
#                 }
#             ],
#             "place_id": "ChIJL1wm9u3DHg0RLvegNXi1hoY",
#             "plus_code": {
#                 "compound_code": "PG3M+C6 Cascais, Portugal",
#                 "global_code": "8CCGPG3M+C6"
#             },
#             "rating": 4.6,
#             "reference": "ChIJL1wm9u3DHg0RLvegNXi1hoY",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 501,
#             "vicinity": "R. de Oitavos, Cascais"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 38.724525,
#                     "lng": -9.158507
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 38.72592922989272,
#                         "lng": -9.157172620107279
#                     },
#                     "southwest": {
#                         "lat": 38.72322957010728,
#                         "lng": -9.159872279892722
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "c47a0e1bc14c2a3ad9421839c418b317c67e253e",
#             "name": "EPIC SANA Lisboa Hotel",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1365,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/117080940670006863207/photos\">EPIC SANA Lisboa</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAcCvenJHMrwtDRgVQvbW5JwiinqhusVjkHTuzEc_0AlLbiM8ew_v9lblvQSBpm2cFSt_RtUS-gTqgaF4VfT5n3auKBR5kwvcCH_58fX9GOeNQaPYFRjAaSZkf7G64StOuEhCDgl1IfUc5k6gHZL7sRxRZGhR5d58WhHPYB6YaL5SIEgm_0BOtWg",
#                     "width": 2048
#                 }
#             ],
#             "place_id": "ChIJzznDs28zGQ0R7JPBDZJ9cm8",
#             "plus_code": {
#                 "compound_code": "PRFR+RH Lisbon, Portugal",
#                 "global_code": "8CCGPRFR+RH"
#             },
#             "rating": 4.6,
#             "reference": "ChIJzznDs28zGQ0R7JPBDZJ9cm8",
#             "scope": "GOOGLE",
#             "types": [
#                 "spa",
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 2361,
#             "vicinity": "Av. Eng. Duarte Pacheco 15, Lisboa"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 38.7701303,
#                     "lng": -9.475667399999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 38.77148947989271,
#                         "lng": -9.474331170107277
#                     },
#                     "southwest": {
#                         "lat": 38.76878982010727,
#                         "lng": -9.47703082989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "8ea0ef9380e42731fb14fc5ac2a08772460585b6",
#             "name": "Convento de S\u00e3o Saturnino Guesthouse",
#             "photos": [
#                 {
#                     "height": 2336,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/104053440122081477705/photos\">Angelika P\u00f6ge</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAmIk6z9fvFWFOFzWZ_ItxCEews0lOvhr0kV3Pm2vsh21mXWta4OW7qjFtP-yMC8Yps7qUrj1ZaKt-_Rw3-kkBesbkBznVPoaAOJpVy41ZNP9UXJmyNxVPRer7I_nSqgqUEhCx0J_rJrArkI6Kh0prr-N7GhRjbh7e1DRWXEE8G4tbcD9_yk8ucA",
#                     "width": 4160
#                 }
#             ],
#             "place_id": "ChIJJYR5apXaHg0RecRDwG8nPzI",
#             "plus_code": {
#                 "compound_code": "QGCF+3P Colares, Portugal",
#                 "global_code": "8CCGQGCF+3P"
#             },
#             "rating": 4.5,
#             "reference": "ChIJJYR5apXaHg0RecRDwG8nPzI",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 40,
#             "vicinity": "Az\u00f3ia, Sintra"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 38.7041392,
#                     "lng": -9.4058204
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 38.70559232989272,
#                         "lng": -9.404480670107278
#                     },
#                     "southwest": {
#                         "lat": 38.70289267010727,
#                         "lng": -9.407180329892721
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "e1973810c1af625c7d9072cf8a1e766f5497abca",
#             "name": "InterContinental Cascais-Estoril",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1152,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/100379489197244494750/photos\">Dan Miller</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA_5yU5V1FuBqcQapB2Qv0jHu9pjuBgPW7Sacd-CdRwKNNY1toQmW2iz_BUKkfMMvrosDmJJemuByWtXfU58K4BenjaOhyqZp-eGArjnBDpYZ5G68dsaWmWHOVioL6Z0qIEhBFbDz4pz6QCnlVm_eVGOUDGhTiNrmpIRiHIXgIo_-HZ_VGTwwi7g",
#                     "width": 2048
#                 }
#             ],
#             "place_id": "ChIJ9dV1bs7FHg0R_8T1arQfoWc",
#             "plus_code": {
#                 "compound_code": "PH3V+MM Estoril, Portugal",
#                 "global_code": "8CCGPH3V+MM"
#             },
#             "rating": 4.7,
#             "reference": "ChIJ9dV1bs7FHg0R_8T1arQfoWc",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 463,
#             "vicinity": "Av. Marginal 8023, Estoril"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 38.696295,
#                     "lng": -9.43835
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 38.69762007989272,
#                         "lng": -9.43725652010728
#                     },
#                     "southwest": {
#                         "lat": 38.69492042010727,
#                         "lng": -9.439956179892723
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "ca713bce17cd7d0cd2faa03cafe260bc0aa8f3e0",
#             "name": "Pestana Cascais",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 788,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/112433852853194351809/photos\">Pestana Cascais Ocean &amp; Conference Aparthotel</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAaQJYVVRyJ-xkS7VAMiWRJy38Uhud74oowhqZr6tbvft4lDXAfL_9vMP7QNH7-LfOA0zJJR7ofi8RF-F0RHqd60nWYCWSvIaKvGt4Io7kGye0TVSigNaWv7QKyjSfoLBdEhBhqUeIzQtS0kqW2AzXZrFtGhR1JzlNUWVS1DQ8bD_EElmFWqaaTg",
#                     "width": 1183
#                 }
#             ],
#             "place_id": "ChIJt6DGbRnEHg0RtVQ6C0k-orc",
#             "plus_code": {
#                 "compound_code": "MHW6+GM Cascais, Portugal",
#                 "global_code": "8CCGMHW6+GM"
#             },
#             "rating": 4.1,
#             "reference": "ChIJt6DGbRnEHg0RtVQ6C0k-orc",
#             "scope": "GOOGLE",
#             "types": [
#                 "spa",
#                 "lodging",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 784,
#             "vicinity": "Av. Manuel J\u00falio Carvalho e Costa 115, Cascais"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 38.7051974,
#                     "lng": -9.3960771
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 38.70654067989273,
#                         "lng": -9.394690920107276
#                     },
#                     "southwest": {
#                         "lat": 38.70384102010728,
#                         "lng": -9.39739057989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "98648e554d522dde258531fd8a94275f6d59c79d",
#             "name": "Palacio Estoril Golf & Spa Hotel",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 667,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/109415310971178054189/photos\">Palacio Estoril Golf &amp; Spa Hotel</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAHMUbmwIK-hPlMrf-Fhmq2mOBouHlQsadylPP7y-rnVuVX4i6ou9ZtJdGdA7JMuhp7rSC_Q_TcQEnU7m_vJBvCyMGkdWhXS-tU-UulNmujV7ehZv2lkqKakprq1fRdz0BEhBcotNK6ymqV_CkNJgqezLQGhSCLFc_ueEJv3MoizkSfDWWGONL_w",
#                     "width": 1001
#                 }
#             ],
#             "place_id": "ChIJweCBlcTFHg0RSrRfIDXIf_M",
#             "plus_code": {
#                 "compound_code": "PJ43+3H Estoril, Portugal",
#                 "global_code": "8CCGPJ43+3H"
#             },
#             "rating": 4.7,
#             "reference": "ChIJweCBlcTFHg0RSrRfIDXIf_M",
#             "scope": "GOOGLE",
#             "types": [
#                 "spa",
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 933,
#             "vicinity": "Rua Particular, Estoril"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 38.796306,
#                     "lng": -9.389562999999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 38.79768662989272,
#                         "lng": -9.388200820107278
#                     },
#                     "southwest": {
#                         "lat": 38.79498697010727,
#                         "lng": -9.390900479892721
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "d18103b4afb54d49179a692f36ed3cd91a6372d6",
#             "name": "Sintra Boutique Hotel",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2187,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/106167753105309033649/photos\">Sintra Boutique Hotel</a>"
#                     ],
#                     "photo_reference": "CmRaAAAADbqTw2yf0JieYAdrWpsT70_GYoTe4ao5ibRB-4jIESFE7zIUQwxvg2qJNAJcE5Q5k2fTyh5x-wYhMfOXDP0MX7YwHaeP4TcVSgKbT34EIukvDZFtG2o70dbRkMC5nDtaEhAADstoq1XiunXDHjPiIzLoGhTJ5HSMHqrb9JVthJa-oseQusuA7w",
#                     "width": 3888
#                 }
#             ],
#             "place_id": "ChIJi-YD9r_aHg0RKdzbG4rMncw",
#             "plus_code": {
#                 "compound_code": "QJW6+G5 Sintra, Portugal",
#                 "global_code": "8CCGQJW6+G5"
#             },
#             "rating": 4.6,
#             "reference": "ChIJi-YD9r_aHg0RKdzbG4rMncw",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "bar",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "clothing_store",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 209,
#             "vicinity": "R. Visc. de Monserrate 48, Sintra"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 38.960247,
#                     "lng": -9.4177929
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 38.96172652989272,
#                         "lng": -9.416343920107279
#                     },
#                     "southwest": {
#                         "lat": 38.95902687010727,
#                         "lng": -9.419043579892723
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "0de8b9d624eb98ee8d154a108b0fc7e1771389b0",
#             "name": "Hotel Vila Gal\u00e9 Ericeira",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1181,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/113469228037243556904/photos\">Vila Gal\u00e9 Ericeira</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAb7NcveF6JavovnfeI0REoiaDjwvGEkIExkydaj0COM_5SCfK_tYvOZtPG9_sWVi2DziOccUWAFuxPwFt7d2uejt48TbT6HpPwSswBPm-08K_kMQvCBh13G0UjdISgxkDEhAuIN7o27aPhtbfm7IwE-daGhTivbuBk9Iz9EqODMionYYadvVnYQ",
#                     "width": 1772
#                 }
#             ],
#             "place_id": "ChIJs9rXhZ00GQ0Rn7_PLu5XG3Q",
#             "plus_code": {
#                 "compound_code": "XH6J+3V Ericeira, Portugal",
#                 "global_code": "8CCGXH6J+3V"
#             },
#             "rating": 4.4,
#             "reference": "ChIJs9rXhZ00GQ0Rn7_PLu5XG3Q",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1579,
#             "vicinity": "Largo dos Navegantes 1, Ericeira"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 38.797498,
#                     "lng": -9.391608999999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 38.79889592989272,
#                         "lng": -9.390231370107278
#                     },
#                     "southwest": {
#                         "lat": 38.79619627010728,
#                         "lng": -9.392931029892722
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "40a561b2294166ed2e5509b95e9a39bccf78e9bb",
#             "name": "Tivoli Sintra Hotel",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1414,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/106078199350459259765/photos\">Hotel Tivoli Sintra</a>"
#                     ],
#                     "photo_reference": "CmRaAAAApaB7HghaAbM7NdqjYu6VkLZTkN5BpdrPntL5OprqU4vasZRxkX13LI9KI6NQzFTMWJO79J-NIQuGbjd5XENQ65TMBuPijS1FVjT3c7w65dm047e6ZxHygA3mUL5xiImFEhCWYV9OG33xSfOoXWjOeQzfGhQ3RLzs9e-bbapT33hRXdCXCF1uPw",
#                     "width": 2121
#                 }
#             ],
#             "place_id": "ChIJjUNdI8DaHg0R6FBfeYSbQAQ",
#             "plus_code": {
#                 "compound_code": "QJW5+X9 Sintra, Portugal",
#                 "global_code": "8CCGQJW5+X9"
#             },
#             "rating": 4,
#             "reference": "ChIJjUNdI8DaHg0R6FBfeYSbQAQ",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 505,
#             "vicinity": "Pra\u00e7a da Rep\u00fablica, Sintra"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 38.7022424,
#                     "lng": -9.4107098
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 38.70357857989272,
#                         "lng": -9.409355070107276
#                     },
#                     "southwest": {
#                         "lat": 38.70087892010728,
#                         "lng": -9.41205472989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png",
#             "id": "d55ebad0e20806af99665ef5bd70ea31ae504d92",
#             "name": "Hotel Cascais Mirage Health & Spa",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2458,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/106780649084505070981/photos\">A Google User</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAdJjnu-xm1ZYjPS-7-IqR951-OHi2xWql5Ty0O_BEANxsFveyi0wN2nU3JOY_jMnfEngKA4H0HuVsfS15vsceU_5VLYZWO0vzmhBllgBaJ1rXfId6xC6e0jHK0iKL-OinEhAitp6KZYexZcSJW4O22YY4GhS8G7yVfAV83wv9L_8v4nYBcrK_Nw",
#                     "width": 4370
#                 }
#             ],
#             "place_id": "ChIJRZ0Jd_DFHg0R5c-kc36v8Ik",
#             "plus_code": {
#                 "compound_code": "PH2Q+VP Cascais, Portugal",
#                 "global_code": "8CCGPH2Q+VP"
#             },
#             "rating": 4.7,
#             "reference": "ChIJRZ0Jd_DFHg0R5c-kc36v8Ik",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1579,
#             "vicinity": "Av. Marginal 8554, Cascais"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 38.7090725,
#                     "lng": -9.1446503
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 38.71041532989272,
#                         "lng": -9.143335020107278
#                     },
#                     "southwest": {
#                         "lat": 38.70771567010728,
#                         "lng": -9.146034679892722
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "3042ee236ec21bbc749ba85e6c5d2169ebc8d732",
#             "name": "Lisbon Old Town Hostel",
#             "photos": [
#                 {
#                     "height": 1536,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/114366769643122046971/photos\">Lisbon Old Town Hostel</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAGeGEHEQejIH8xW_H0dwWzjDpnJUBmr7MuvUoH9ty09Nj2DMf_RAUdJjsarBYroBw6ZGVZuand0f5g5BsXKBZ1ufKaVwIVq83b80xcbqKsdAswZZZPUWZgx5cnQqbdIgtEhDdk79s9M8s44dD_zAK3TsGGhRM0VmHD39rJycKSeXaWIFjh2CRWA",
#                     "width": 2304
#                 }
#             ],
#             "place_id": "ChIJg6z2PX40GQ0RxG0ht9lA2mk",
#             "plus_code": {
#                 "compound_code": "PV54+J4 Lisbon, Portugal",
#                 "global_code": "8CCGPV54+J4"
#             },
#             "rating": 4.7,
#             "reference": "ChIJg6z2PX40GQ0RxG0ht9lA2mk",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 239,
#             "vicinity": "R. Ata\u00edde 26A, Lisboa"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 38.6947802,
#                     "lng": -9.214832999999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 38.69624632989272,
#                         "lng": -9.213484920107277
#                     },
#                     "southwest": {
#                         "lat": 38.69354667010728,
#                         "lng": -9.21618457989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "218380269b299dc374acb97518dab4bd52940788",
#             "name": "Pal\u00e1cio do Governador",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2336,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/107112200031728286699/photos\">Hotel Pal\u00e1cio do Governador</a>"
#                     ],
#                     "photo_reference": "CmRaAAAARr7GE-QESgTcH9SpGHP1LZbbdn0KPZ00cDyozcWvyQGbJxTjPFaHoO-OUp03Oz65CLwv6Z2C1UejSEfujGYtaBp9J8GeUWjg2ENXSwoxdoIHzUfinNOZN2WHBalIdIqHEhDSbKkfmti-T8KwuYfJOqVEGhT6JmfqB_rIMt9btbaIIRuNyaCcmQ",
#                     "width": 3500
#                 }
#             ],
#             "place_id": "ChIJ8VbcT2jLHg0RwSFQok0NE-Y",
#             "plus_code": {
#                 "compound_code": "MQVP+W3 Lisbon, Portugal",
#                 "global_code": "8CCGMQVP+W3"
#             },
#             "rating": 4.7,
#             "reference": "ChIJ8VbcT2jLHg0RwSFQok0NE-Y",
#             "scope": "GOOGLE",
#             "types": [
#                 "spa",
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 544,
#             "vicinity": "R. Bartolomeu Dias 117, Lisboa"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 38.7947932,
#                     "lng": -9.3841894
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 38.79607272989272,
#                         "lng": -9.382838870107276
#                     },
#                     "southwest": {
#                         "lat": 38.79337307010728,
#                         "lng": -9.38553852989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "23a3f9b1ab631569766e70d5b2970530373c9bbf",
#             "name": "Quinta das Murtas",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 1364,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/104500061498586757975/photos\">Quinta das murtas</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAbQnD-MLZDRPfR4JfrMpWBIopXCCJJf781_uwFUoS8G0FS2oNZUq5WnnJUFFXIundgHkrp3NqA3w8r7LOEtpIN1bV-duSWCpfej7DoO9NO7b1dipxeMZ9pWTxYL4L0osVEhASqopRZRkErNkBQylPNOE3GhSZE8ab35-JSbZb0-8lBjXsDN8JcQ",
#                     "width": 2048
#                 }
#             ],
#             "place_id": "ChIJ5Ya_g77aHg0RLiKD7ZmG740",
#             "plus_code": {
#                 "compound_code": "QJV8+W8 Sintra, Portugal",
#                 "global_code": "8CCGQJV8+W8"
#             },
#             "rating": 4.3,
#             "reference": "ChIJ5Ya_g77aHg0RLiKD7ZmG740",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 326,
#             "vicinity": "R. Eduardo Van-Zeller 4, Sintra"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 38.8172513,
#                     "lng": -9.475624
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 38.81856267989273,
#                         "lng": -9.474109370107278
#                     },
#                     "southwest": {
#                         "lat": 38.81586302010728,
#                         "lng": -9.476809029892722
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "bef1c7049b674e2745be5553b9cbb019eed48e22",
#             "name": "Arribas Sintra Hotel",
#             "photos": [
#                 {
#                     "height": 793,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/110136034296297511284/photos\">Hotel Arribas</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAcDJQaUMHgUA9wObKDUnM0Sgk9Wfczq4avqH_W3PiWvBi9R8jyPzRrTOEnQHFliiRgeZKM_U1TYu-sTuEhoa-q_XiR4j4_yGfphWZyEiZ02ota2pU3fMsfpvfpcJQLvisEhD_17J98tQkREKmuWyWWoaRGhQaAdicwpVTLvJTLrI4vTjfA4Uqsg",
#                     "width": 1200
#                 }
#             ],
#             "place_id": "ChIJZyhe3mbcHg0RjnKj-1mwsCo",
#             "plus_code": {
#                 "compound_code": "RG8F+WQ Colares, Portugal",
#                 "global_code": "8CCGRG8F+WQ"
#             },
#             "rating": 4.4,
#             "reference": "ChIJZyhe3mbcHg0RjnKj-1mwsCo",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1208,
#             "vicinity": "Av. Alfredo Coelho 28, Colares"
#         }
#     ],
#     "status": "OK"
# }
# {
#     "html_attributions": [],
#     "next_page_token": "CrQCJAEAALWDtw0Lg9JezIHC2M3WAooCU5Dywa7m2iJ6q_jNE5IrJEHOEceXaHipBlg7DRF5R2lH5pjNIIzPGB7sNcSfLf3lfiSCDDsqmCvOJ_CveQOelaAfSxElixbxQRL9H-QzuBDakV10seP-tPwEAqhSzyAx7ManlU_lstAKMvAFbppV_W66y_6ARF0QJgQ2JaAbBFuUXXpUVURm4esMLiP1lZ3nJwIp8LnzwerzzqpumrLmbKZQUw2cnNIUXs1QLL5X6Bb2D3FtwdjFgXwYNQLsE6KLix2PK0dQ7PPYuYwvYwix0-vZb8UP9a9Qw53P0lgblHE0qx3ztOUxfwQQPefChQ1MiWrbVcLhJltoozY4VRqEPhJlCOj9afBXV7AiPUuwF5qNT2dny9xqz6-Z1u9z7jsSECnCzoADtOjxVT6QKYKRI4saFFEo3r-WUw3jCWdQxtyYYJ9f-Z_n",
#     "results": [
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 25.5440843,
#                     "lng": 87.5725009
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 25.54528657989272,
#                         "lng": 87.57383287989272
#                     },
#                     "southwest": {
#                         "lat": 25.54258692010728,
#                         "lng": 87.57113322010727
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "9d99638e9a81def1e1bf9614c0e6d1a0bdb51ffb",
#             "name": "Hotel Satkar",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2448,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/111101498347926435235/photos\">Suman Sarkar</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAaspmycFZc2Mif1CI7-jOc-4Nkdb1WhKkpyGJEvCPxgLBzJV4EuoD5VSI3u8GMf4O9q-1Glbe9-7S2YottkzYWgR5BeZRjmQAADrUnnf-KzqQjQpPz5DcLP3SYCVeyYQvEhAYo-gVq5CjM388OfbieRTGGhRGDsES10JMy7kw2iNIpUJPkaOCBQ",
#                     "width": 3264
#                 }
#             ],
#             "place_id": "ChIJOVRu7oap-jkRzCXcIZ5Eldk",
#             "plus_code": {
#                 "compound_code": "GHVF+J2 Katihar, Bihar, India",
#                 "global_code": "7MQ9GHVF+J2"
#             },
#             "rating": 3.6,
#             "reference": "ChIJOVRu7oap-jkRzCXcIZ5Eldk",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 756,
#             "vicinity": "Rajendra Prasad Path, New Market, Katihar"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 25.7705571,
#                     "lng": 87.47839119999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 25.77190462989272,
#                         "lng": 87.47974572989271
#                     },
#                     "southwest": {
#                         "lat": 25.76920497010728,
#                         "lng": 87.47704607010726
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "1cfb31ca8d2b6bb70deb057a9b47e28378669fd9",
#             "name": "Wyynd Hotels - Rudra Residency",
#             "photos": [
#                 {
#                     "height": 4096,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/106409662153276713091/photos\">A Google User</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAKr9PxqgrtIFjyWtnxIXmH74d51ol-4rRR4Cp_9ZpPrOhtVB6NsDT5VGp8-kw2mhN4dg1sgKkZwpyTkil7pk_i61I_JSaQEQXlmAv5Fl_6byJ2FEKIdJkYL_iS2GL7dmjEhA1MtjY4MyVrvw8nVgoDwOBGhQKr8ITxPmm3dHv6_okHQIsgopZwQ",
#                     "width": 2304
#                 }
#             ],
#             "place_id": "ChIJYVqIbW357zkRJdKpPoQo8TU",
#             "plus_code": {
#                 "compound_code": "QFCH+69 Purnia, Bihar, India",
#                 "global_code": "7MQ9QFCH+69"
#             },
#             "rating": 3.6,
#             "reference": "ChIJYVqIbW357zkRJdKpPoQo8TU",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 137,
#             "vicinity": "Maa Tara Complex , Jhanda Chowk, Bhatta Bazar, Purnia"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 25.7731241,
#                     "lng": 87.480604
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 25.77447462989272,
#                         "lng": 87.48195267989271
#                     },
#                     "southwest": {
#                         "lat": 25.77177497010728,
#                         "lng": 87.47925302010728
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "553dcdf39cb76af7a86d1a7146b1f8e211ca3ca6",
#             "name": "Hotel sanjay",
#             "photos": [
#                 {
#                     "height": 1011,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/103379829851057967229/photos\">Hotel sanjay .</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAPDuGLySWhk8tO4CjHnhoNnuVOC5_5Oqn7rOvRjFHZvbYYtrzIxDZmq-xbIOs3CzggyNiuGKGHB-Wh9nTtjBwZKFVjHHpsHjvQHWq61reWIDPtC0Qrwk58m6Lgk9LgJ8_EhDDvnmxE6ty3RiPSiAst8utGhQEBUgm74LTW73HhUc1lvYzNTwbeg",
#                     "width": 1098
#                 }
#             ],
#             "place_id": "ChIJAQAA8Gz57zkR1zauWilcYno",
#             "plus_code": {
#                 "compound_code": "QFFJ+66 Navratan Hatta, Purnia, Bihar, India",
#                 "global_code": "7MQ9QFFJ+66"
#             },
#             "rating": 3.7,
#             "reference": "ChIJAQAA8Gz57zkR1zauWilcYno",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 530,
#             "vicinity": "Bhatta Bazar, Navratan Hatta, Purnia"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 25.772201,
#                     "lng": 87.47776999999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 25.77361347989272,
#                         "lng": 87.47917927989272
#                     },
#                     "southwest": {
#                         "lat": 25.77091382010728,
#                         "lng": 87.47647962010727
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "9ff912d38f1c6bdd6e63235936a484ec81d493fc",
#             "name": "Hotel Biraj International",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1280,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/108477093074208757648/photos\">Hotel Biraj International</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAUQTcFuSFS5Kpxh8_mWJ-VMs8OO-H--ADJ3Fz31pA01E4ev9iHBIfD_Q7oHBATfw3W6RQT0hl-jbbnHmeb-g35RIz7FIGqt0ZNGyiF8a8ULxlGLUW8FgkMbxvBahVCtW7EhAThXNi-7QqKDjzl0KYmMKmGhTfvgBsETCnzU4HKOo4OQ1YoaRhfg",
#                     "width": 960
#                 }
#             ],
#             "place_id": "ChIJGWLNiXL57zkRs0a_Y_iDwdA",
#             "plus_code": {
#                 "compound_code": "QFCH+V4 Navratan Hatta, Purnia, Bihar, India",
#                 "global_code": "7MQ9QFCH+V4"
#             },
#             "rating": 3.7,
#             "reference": "ChIJGWLNiXL57zkRs0a_Y_iDwdA",
#             "scope": "GOOGLE",
#             "types": [
# ...
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 23.02809507989272,
#                         "lng": 72.58717532989272
#                     },
#                     "southwest": {
#                         "lat": 23.02539542010728,
#                         "lng": 72.58447567010727
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "828f831f8db585ed48bb280bf4145302f0f9541f",
#             "name": "Hotel Prime",
#             "photos": [
#                 {
#                     "height": 2322,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/100669456962298020613/photos\">Rajesh Rai</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAXJCd76--hOm7iF1CbOoyXkEG5ehvUWuoXsbKC2YiaHgHfxV1_taQ5Io7LCf9-Yc5Ih7hxLp5As5Y-m1t6CUzVZXp3700KSCT155E3CgVKcUGrK1HcgDzJ1CoEpOhm_1jEhDZTYLnpSJ31t6nWTkZ6U5UGhTTrdjPRNrEKXkuKeZfbYMpvb8Alw",
#                     "width": 4128
#                 }
#             ],
#             "place_id": "ChIJWa4GKkmEXjkRhC_0seN_Rro",
#             "plus_code": {
#                 "compound_code": "2HGP+M9 Ahmedabad, Gujarat, India",
#                 "global_code": "7JMJ2HGP+M9"
#             },
#             "rating": 3.8,
#             "reference": "ChIJWa4GKkmEXjkRhC_0seN_Rro",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 467,
#             "vicinity": "2nd Floor,Vishal Commercial Centre Opp LIC Building, Relief Rd, Old City, Bhadra, Ahmedabad"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 23.070394,
#                     "lng": 72.5218111
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 23.07174967989272,
#                         "lng": 72.52314022989272
#                     },
#                     "southwest": {
#                         "lat": 23.06905002010728,
#                         "lng": 72.52044057010728
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "9957111fa6f4b95bae2b73bad0cdda637782d823",
#             "name": "Hotel Citizen",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1920,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/101156095368558522888/photos\">Manish Patel</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAO2M-Dw1n8ClFb8ECn2hY6zU1-S_yWC4-AaimQO8MzuTvg2CVEbvNhQ2_Y4O2vaQobhn2aEfLS_jRXRVBlCIQ_yCB3t5mowvntStAliyRXsHZ4vZXEsIdQCo3nHY2q5O6EhCkpI0lQov-G_Ync3rdaUrIGhRHkLPjaiJDQRLnWqUoRiHYhSaA4Q",
#                     "width": 2560
#                 }
#             ],
#             "place_id": "ChIJ0bknI02DXjkRr_EkOBWMZWo",
#             "plus_code": {
#                 "compound_code": "3GCC+5P Ahmedabad, Gujarat, India",
#                 "global_code": "7JMJ3GCC+5P"
#             },
#             "rating": 3.5,
#             "reference": "ChIJ0bknI02DXjkRr_EkOBWMZWo",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 100,
#             "vicinity": "Shop No. 1 & 2, 2nd Floor, Above Co-Operative Bank, Science City Road, Sola, Ahmedabad"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 23.045981,
#                     "lng": 72.57002299999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 23.04713252989272,
#                         "lng": 72.57138947989272
#                     },
#                     "southwest": {
#                         "lat": 23.04443287010728,
#                         "lng": 72.56868982010727
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "732847be8468f0df907f5024aebcf57ce1c88c6d",
#             "name": "Hotel Damjis",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3746,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/112732658456010649347/photos\">A Google User</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAg-qGyjiP-R5k_Sx_f1Dx7WgEDQPEaDmbSJaDp3vL4K8hnKv0d0tassvp0xPCWN5LgddzEl8HK38shxV33gHdEqcm-jvlQfb9wlKv40oIW8gX6-LcmCL7NDJfcKwkT-mkEhAo8IEPL1jYsoJvbBqVgyzsGhTJIQO468jyfma0r8rbKYSWa11C5Q",
#                     "width": 4762
#                 }
#             ],
#             "place_id": "ChIJrykyTGKEXjkR448dDKEZC0k",
#             "plus_code": {
#                 "compound_code": "2HWC+92 Usmanpura, Ahmedabad, Gujarat, India",
#                 "global_code": "7JMJ2HWC+92"
#             },
#             "rating": 3,
#             "reference": "ChIJrykyTGKEXjkR448dDKEZC0k",
#             "scope": "GOOGLE",
#             "types": [
#                 "spa",
#                 "lodging",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 166,
#             "vicinity": "Cross Road, Ashram Rd, opp. AUDA Office, Sattar Taluka Society, Usmanpura, Ahmedabad"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 23.269815,
#                     "lng": 72.64366199999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 23.27120917989272,
#                         "lng": 72.64472122989271
#                     },
#                     "southwest": {
#                         "lat": 23.26850952010728,
#                         "lng": 72.64202157010726
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "1eb957eba05df93e18c41e819618ed7661052acb",
#             "name": "Ghunghat Hotel",
#             "photos": [
#                 {
#                     "height": 3840,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/107949770216317185199/photos\">Ubaidqaiyoom Badi</a>"
#                     ],
#                     "photo_reference": "CmRZAAAAyUgZwfaeb4sNLvgCMegqf_KLWEjT7yxfbkIWX5Zy_EvKZaXuwUMxiotaGrXjE86RutNwWdnnHHcNSzaOwVo0LgcGcf6g-1BKTOGShwpsnAx4IA6AIORiZr2pjn9YFRbGEhA1kgaSuMJSIiiCohXPv4tnGhRPAx4P6XnrAcwWsNkWPEYH1rA2pg",
#                     "width": 5760
#                 }
#             ],
#             "place_id": "ChIJ____P4orXDkR6CfZtkHf2N8",
#             "plus_code": {
#                 "compound_code": "7J9V+WF Gandhinagar, Gujarat, India",
#                 "global_code": "7JMJ7J9V+WF"
#             },
#             "rating": 4.1,
#             "reference": "ChIJ____P4orXDkR6CfZtkHf2N8",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 969,
#             "vicinity": "Sector -26, \"K\" Road, Near GIDC, Gandhinagar -Mansa Road,, Gandhinagar"
#         }
#     ],
#     "status": "OK"
# }
#     City ID                      City  Cloudiness Country        Date  \
# 0        50                   Colares           0      PT  1570758452
# 1        57                      Jian           0      IN  1570758453
# 2        67                 Iranshahr           0      IR  1570758454
# 3        75           Phra Phutthabat           0      TH  1570758455
# 4        95              Saint-Joseph           0      FR  1570758458
# 5       142                    Hutang           0      CN  1570758464
# 6       159                    Bismil           0      TR  1570758466
# 7       177          Samdrup Jongkhar           0      IN  1570758469
# 8       223                 Morondava           0      MG  1570758475
# 9       262                    Motala           0      IN  1570758480
# 10      343           Firozpur Jhirka           0      IN  1570758490
# 11      345                  Mandawar           0      IN  1570758491
# 12      353                     Tabas           0      IR  1570758492
# 13      362             Puerto Suarez           0      BO  1570758493
# 14      389                     Nizwa           0      OM  1570758496
# 15      390                  Am Timan           0      TD  1570758497
# 16      469              Keetmanshoop           0     NaN  1570758507
# 17      479                       Jos           0      NG  1570758508
# 18      484  Sao Gabriel da Cachoeira           0      BR  1570758508
# 19      519                  Matagami           0      NG  1570758513
# 20      535                      Rome           0      IT  1570758515
# 21      537                     Mansa           0      IN  1570758515
# 22      613                   Colares           0      PT  1570758452
# 23      620                      Jian           0      IN  1570758453
# 24      630                 Iranshahr           0      IR  1570758454
# 25      638           Phra Phutthabat           0      TH  1570758455
# 26      658              Saint-Joseph           0      FR  1570758458
# 27      705                    Hutang           0      CN  1570758464
# 28      722                    Bismil           0      TR  1570758466
# 29      740          Samdrup Jongkhar           0      IN  1570758469
# 30      786                 Morondava           0      MG  1570758475
# 31      825                    Motala           0      IN  1570758480
# 32      906           Firozpur Jhirka           0      IN  1570758490
# 33      908                  Mandawar           0      IN  1570758491
# 34      916                     Tabas           0      IR  1570758492
# 35      925             Puerto Suarez           0      BO  1570758493
# 36      952                     Nizwa           0      OM  1570758496
# 37      953                  Am Timan           0      TD  1570758497
# 38     1032              Keetmanshoop           0     NaN  1570758507
# 39     1042                       Jos           0      NG  1570758508
# 40     1047  Sao Gabriel da Cachoeira           0      BR  1570758508
# 41     1082                  Matagami           0      NG  1570758513
# 42     1098                      Rome           0      IT  1570758515
# 43     1100                     Mansa           0      IN  1570758515
#
#     Humidity    Lat     Lng  Max Temp  Wind Speed  \
# 0         55  38.80   -9.45     64.99        3.36
# 1         68  25.65   87.89     82.15        2.39
# 2         22  27.21   60.69     79.16        2.66
# 3         79  14.72  100.80     88.00        1.72
# 4         87  43.56    6.97     60.80        3.36
# 5         57  29.22  119.85     86.14        2.38
# 6         41  37.85   40.66     64.40        2.24
# 7         65  26.80   91.50     69.44        3.06
# 8         60 -20.30   44.28     73.98        1.68
# 9         69  20.68   76.21     77.04        3.32
# 10        48  27.79   76.95     77.92        2.82
# 11        62  29.49   78.13     74.75        2.53
# 12        28  33.60   56.92     69.80        4.70
# 13        51 -18.96  -57.80     80.33        4.71
# 14        51  22.93   57.53     75.79        0.63
# 15        82  11.04   20.28     73.18        1.91
# 16        15 -26.57   18.15     60.80        3.36
# 17        88   9.92    8.90     65.62        4.23
# 18        89  -0.13  -67.09     73.42        1.80
# 19        90   9.67    8.40     67.75        3.06
# 20        87  41.89   12.48     63.00        3.36
# 21        78  23.43   72.66     73.40        2.24
# 22        55  38.80   -9.45     64.99        3.36
# 23        68  25.65   87.89     82.15        2.39
# 24        22  27.21   60.69     79.16        2.66
# 25        79  14.72  100.80     88.00        1.72
# 26        87  43.56    6.97     60.80        3.36
# 27        57  29.22  119.85     86.14        2.38
# 28        41  37.85   40.66     64.40        2.24
# 29        65  26.80   91.50     69.44        3.06
# 30        60 -20.30   44.28     73.98        1.68
# 31        69  20.68   76.21     77.04        3.32
# 32        48  27.79   76.95     77.92        2.82
# 33        62  29.49   78.13     74.75        2.53
# 34        28  33.60   56.92     69.80        4.70
# 35        51 -18.96  -57.80     80.33        4.71
# 36        51  22.93   57.53     75.79        0.63
# 37        82  11.04   20.28     73.18        1.91
# 38        15 -26.57   18.15     60.80        3.36
# 39        88   9.92    8.90     65.62        4.23
# 40        89  -0.13  -67.09     73.42        1.80
# 41        90   9.67    8.40     67.75        3.06
# 42        87  41.89   12.48     63.00        3.36
# 43        78  23.43   72.66     73.40        2.24
#
#                                            Hotel Name
# 0                             Sheraton Cascais Resort
# 1                                        Hotel Satkar
# 2                                   هتل و رستوران قصر
# 3                             Kantary Hotel Ayutthaya
# 4   Hôtel ibis budget Nice Aéroport Promenade des ...
# 5                                         Yindu Hotel
# 6                       Radisson Blu Hotel Diyarbakir
# 7                         Maruti Hotel and restaurant
# 8                               Hotel maeva morondava
# 9   Hotel Aaditya Palace pure veg family restauran...
# 10                          Sparrow Inn by MGB Hotels
# 11                  Hometel Roorkee - A Sarovar Hotel
# 12                                       Bahman Hotel
# 13                              Nacional Palace Hotel
# 14                                     Al Diyar Hotel
# 15
# 16                              Bird's Mansions Hotel
# 17                                    The Point Hotel
# 18                                  Hotel Deus Me Deu
# 19                                         HBC Resort
# 20                             Hotel Roma Tor Vergata
# 21                                      Hotel Sanmati
# 22                            Sheraton Cascais Resort
# 23                                       Hotel Satkar
# 24                                  هتل و رستوران قصر
# 25                            Kantary Hotel Ayutthaya
# 26  Hôtel ibis budget Nice Aéroport Promenade des ...
# 27                                        Yindu Hotel
# 28                      Radisson Blu Hotel Diyarbakir
# 29                        Maruti Hotel and restaurant
# 30                              Hotel maeva morondava
# 31  Hotel Aaditya Palace pure veg family restauran...
# 32                          Sparrow Inn by MGB Hotels
# 33                  Hometel Roorkee - A Sarovar Hotel
# 34                                       Bahman Hotel
# 35                              Nacional Palace Hotel
# 36                                     Al Diyar Hotel
# 37
# 38                              Bird's Mansions Hotel
# 39                                    The Point Hotel
# 40                                  Hotel Deus Me Deu
# 41                                         HBC Resort
# 42                             Hotel Roma Tor Vergata
# 43                                      Hotel Sanmati

# %%
# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
# Marker added to mark hotels
markers = gmaps.marker_layer(locations,
    info_box_content=[f"Hotel loc: {rate}" for rate in hotel_info])

fig.add_layer(markers)

# Display Map
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
